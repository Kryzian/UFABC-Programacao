# %% [markdown]
# # Recebendo/Lendo dados
#
# Na Unidade 1, a entrada de dados foi feita diretamente no programa, atribuindo um valor fixo para variável.
#
# Nesta unidade veremos como receber dados do usuário.
#
# Para receber dados do usuário, utilizamos a função ``input``. Ela recebe como parâmetro uma mensagem ao usuário.
#
# Execute a célula abaixo. Deve aparecer uma caixa para você digitar o valor de C.
# Após digitar o valor para C, pressione a tecla enter.

# %%
C = input("Digite a temperatura em Celsius: ")
print("A temperatura digitada é", C ,"graus Celsius")
# Out:
# Digite a temperatura em Celsius: 11
# A temperatura digitada é 11 graus Celsius

# %% [markdown]
# **O `input ` considera como padrão o que usuário digita como um texto**. Abaixo digite 10 como o valor para C.
#
# Veja o que acontece quando tentamos calcular C+C.

# %%
C = input("Digite a temperatura em Celsius: ")
print("A temperatura digitada é", C,"graus Celsius")
D = C+C
print("C+C é", D)
# Out:
# Digite a temperatura em Celsius: 36
# A temperatura digitada é 36 graus Celsius
# C+C é 3636

# %% [markdown]
# O valor de D é 1010 quando o valor de C é 10. Por quê?
#
# É porque, quando lidamos com textos, a operação ``+`` é a operação de concatenar (grudar) os textos. Ou seja D é ``"10"+"10"``, que é ``"1010"``.
#
# Para que C seja considerado como número, temos que fazer uma conversão.
#
# Abaixo recebemos o valor na variável ``C_texto`` e convertemos para um número que possivelmente pode ter casas decimais.
#
# Este tipo de número é chamado de ``float``.

# %%
C_texto = input("Digite a temperatura em Celsius: ")
C = float(C_texto)
print("A temperatura digitada é",C,"graus Celsius")
D = C+C
print("C+C é", D)
# Out:
# Digite a temperatura em Celsius: 46
# A temperatura digitada é 46.0 graus Celsius
# C+C é 92.0

# %% [markdown]
# Na verdade, podemos usar a própria variável ``C`` como a seguir:

# %%
C = input("Digite a temperatura em Celsius: ")
C = float(C)
print("A temperatura digitada é",C,"graus Celsius")
D = C+C
print("C+C é", D)
# Out:
# Digite a temperatura em Celsius: 9
# A temperatura digitada é 9.0 graus Celsius
# C+C é 18.0

# %% [markdown]
# Ou até mesmo, fazer em uma única linha (juntar as primeiras duas linhas de código acima em uma única linha):

# %%
C = float(input("Digite a temperatura em Celsius: "))
print("A temperatura digitada é",C,"graus Celsius")
D = C+C
print("C+C é", D)
# Out:
# Digite a temperatura em Celsius: 88
# A temperatura digitada é 88.0 graus Celsius
# C+C é 176.0

# %% [markdown]
# Você pode usar qual opção preferir. É bem comum fazer em uma única linha.
#
# Veja mais um exemplo.
#
# Suponha que você queira dividir $d$ reais igualmente entre $n$ pessoas.
#
# Nesse caso, $d$ é um número possivelmente com casas decimais e $n$ é um número inteiro.
#
# Para números inteiros, ao invés de ``float``, usamos ``int``:

# %%
d = float(input("Digite a quantidade de dinheiro: "))
n = int(input("Digite o número de pessoas.")) 
r = d/n
print("Cada pessoa vai receber",r,"reais")
# Out:
# Digite a quantidade de dinheiro: 400
# Digite o número de pessoas.50
# Cada pessoa vai receber 8.0 reais

# %% [markdown]
# ## Exercício: quilômetros percorridos
#
# Considere um carro com tanque com capacidade $C$ em litros e eficiência $E$ em km/litro. Queremos saber quantos quilômetros o carro anda com $C$ litros (assumindo que a eficiência vai ser exata).
#
# Faça um programa que
# - Recebe o valor de $C$
# - Recebe o valor de $E$
# - Mostre a resposta formatada com duas casas decimais como neste exemplo:
# O carro vai andar 256.79 quilômetros.

# %%
C = int(input("Digite o valor em litros da capacidade do carro: "))
E = float(input("digite o valor da Eficiência em km/litro: "))
Distancia = C*E
print("O carro anda",Distancia,"quilometros com", C, "litros")
# Out:
# Digite o valor em litros da capacidade do carro: 40
# digite o valor da Eficiência em km/litro: 11.9
# O carro anda 476.0 quilometros com 40 litros

# %% [markdown]
# <hr>

# %% [markdown]
# # Observações importantes.

# %% [markdown]
# **Em exercícios de correção automática no Moodle:**
# - **Nunca coloque mensagens no `input() `**. O computador não precisa da mensagem e o corretor automático pode dar errado por causa disso. Use somente `input() `. Veja exemplos no Notebook com alguns exercícios resolvidos.
# - **Siga a formatação da resposta exatamente como pedido e sem mensagens extras.** Caso contrário, o corretor automático pode dar errado.
