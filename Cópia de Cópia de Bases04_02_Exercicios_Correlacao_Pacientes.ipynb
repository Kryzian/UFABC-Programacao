# %% [markdown]
# ## Exercícios - **Correlação e Regressão** - Base de Dados Paciente

# %% [markdown]
# ```
# (*) Este caderno possui elementos inspirados em material preparado pelo Prof. Ronaldo Prati
# ```

# %%
import pandas as pd 
#https://drive.google.com/file/d/1foZsAIE3sSoFf53ENs9QCQ29ZqcMOxac/view?usp=sharing
codigo = "1foZsAIE3sSoFf53ENs9QCQ29ZqcMOxac"
file = "https://drive.google.com/u/3/uc?id=" + codigo + "&export=download"
# Base de Dados de Pacientes
# Note a especificação de SEPARADOR (ponto e vírgula)
# Note a especificação de VÍRGULA DECIMAL
pacientes = pd.read_csv(file, sep = ";",decimal=",")
#df = pd.read_csv(file)
print(pacientes)
# Out:
#     Ident  Idade  Altura   Peso  ...  Sistolica  Diastolica  Colesterol   IMC
# 0       1     58    1.80   76.1  ...        125          78         522  23.5
# 1       2     22    1.68   64.9  ...        107          54         127  23.0
# 2       3     32    1.82   80.7  ...        126          81         740  24.3
# 3       4     31    1.74   79.1  ...        110          68          49  26.0
# 4       5     28    1.72   68.7  ...        110          66         230  23.3
# 5       6     46    1.76   75.1  ...        107          83         316  24.3
# 6       7     41    1.69   60.8  ...        113          71         590  21.3
# 7       8     56    1.71   90.7  ...        126          72         466  31.1
# 8       9     20    1.73   78.8  ...        137          85         121  26.2
# 9      10     54    1.67   62.6  ...        110          71         578  22.5
# 10     11     17    1.60   70.3  ...        109          65          78  27.5
# ...

# %% [markdown]
# ## Matriz de Correlação

# %% [markdown]
# A matriz de correlação mostra a correlação entre todos os atributos.

# %%
import pandas as pd 
#https://drive.google.com/file/d/1foZsAIE3sSoFf53ENs9QCQ29ZqcMOxac/view?usp=sharing
codigo = "1foZsAIE3sSoFf53ENs9QCQ29ZqcMOxac"
file = "https://drive.google.com/u/3/uc?id=" + codigo + "&export=download"
pacientes = pd.read_csv(file, sep = ";",decimal=",")
pacientes.corr()
# Out:
#                Ident     Idade    Altura  ...  Diastolica  Colesterol       IMC
# Ident       1.000000 -0.187703 -0.053381  ...   -0.038962   -0.034092  0.314567
# Idade      -0.187703  1.000000  0.257627  ...    0.415744    0.254440  0.022847
# Altura     -0.053381  0.257627  1.000000  ...    0.138105   -0.314939 -0.180235
# Peso        0.239563  0.170820  0.492997  ...    0.465084   -0.091743  0.763895
# Pulsacao    0.163596 -0.154941 -0.225172  ...   -0.140562    0.027092  0.181878
# Sistolica   0.218415  0.344139  0.000600  ...    0.567038    0.183739  0.408384
# Diastolica -0.038962  0.415744  0.138105  ...    1.000000    0.216238  0.430112
# Colesterol -0.034092  0.254440 -0.314939  ...    0.216238    1.000000  0.161363
# IMC         0.314567  0.022847 -0.180235  ...    0.430112    0.161363  1.000000
#
# [9 rows x 9 columns]

# %% [markdown]
# Podemos usar a biblioteca `seaborn` para criar um gráfico de mapa de calor, para facilitar a visualização da matriz de correlação. Note que as cores mais quentes (em direção ao vermelho) indicam os maiores valores.

# %%
import seaborn as sns

sns.heatmap(pacientes.corr(),  vmin=-1, vmax=1, center=0, annot = True, cmap= 'coolwarm')

# %% [markdown]
# A visualização acima foi baseada nesse [link](https://towardsdatascience.com/better-heatmaps-and-correlation-matrix-plots-in-python-41445d0f2bec).

# %% [markdown]
# ## Exercícios

# %% [markdown]
# ### Exercícios 01
#
# Identifique a maior correlação na matriz acima e escreva a instrução python para exibir a correlação entre os dois atributos.

# %%
import pandas as pd 
#https://drive.google.com/file/d/1foZsAIE3sSoFf53ENs9QCQ29ZqcMOxac/view?usp=sharing
codigo = "1foZsAIE3sSoFf53ENs9QCQ29ZqcMOxac"
file = "https://drive.google.com/u/3/uc?id=" + codigo + "&export=download"
pacientes = pd.read_csv(file, sep = ";",decimal=",")
pacientes['Peso'].corr(pacientes['IMC'])
# Out:
# 0.7638948233592583

# %% [markdown]
# ### Exercícios 02
#
# Plote um gráfico de dispersão para os dois atributos de maior correlação. Faça um gráfico com e sem a reta de regressão.

# %%
# Gráfico de dispersão (sem a reta de regressão)
#Digite sua resposta aqui
import pandas as pd 
#https://drive.google.com/file/d/1foZsAIE3sSoFf53ENs9QCQ29ZqcMOxac/view?usp=sharing
codigo = "1foZsAIE3sSoFf53ENs9QCQ29ZqcMOxac"
file = "https://drive.google.com/u/3/uc?id=" + codigo + "&export=download"
pacientes = pd.read_csv(file, sep = ";",decimal=",")
pacientes.plot(x='Peso', y='IMC', kind = 'scatter')

# %%
# Gráfico de dispersão (com a reta de regressão)
import pandas as pd 
#https://drive.google.com/file/d/1foZsAIE3sSoFf53ENs9QCQ29ZqcMOxac/view?usp=sharing
codigo = "1foZsAIE3sSoFf53ENs9QCQ29ZqcMOxac"
file = "https://drive.google.com/u/3/uc?id=" + codigo + "&export=download"
pacientes = pd.read_csv(file, sep = ";",decimal=",")
import seaborn as sns
gra = sns.lmplot(x= "Peso", y= "IMC", data = pacientes)

# %% [markdown]
# ### Exercícios 03
#
# Escreva instruções para exibir os valores de "m" e "b" da equação da reta tendo o IMC como variável **dependente** e o PESO como variável **independente**.

# %%
# Digite sua resposta aqui
# Out:
#   File "<ipython-input-11-a0d056cd4ef2>", line 2
#     g= sns.(x= "Peso", y= "IMC", data = pacientes).min()
#            ^
# SyntaxError: invalid syntax

# %% [markdown]
# ### Exercícios 04
#
# Escreva instruções para calcular e mostrar o valor de Y para X =90.7. Analise o resultado comparando com os valores de IMC na tabela para PESOS ao redor de 90.7.

# %%
# Digite sua resposta aqui

# %% [markdown]
# Escreva instruções para calcular e mostrar o valor de Y para X =60.0. Analise o resultado comparando com os valores de IMC na tabela para PESOS ao redor de 60.0.

# %%
# Digite sua resposta aqui

# %% [markdown]
# ### Exercícios 05
#
# Gere o modelo para todos os valores de IMC da tabela.

# %%
# Digite sua resposta aqui

# %% [markdown]
# ### Exercícios 06
#
# Calcule e mostre o coeficiente de determinação da relação entre as variáveis IMC e PESO.

# %%
# Digite sua resposta aqui
