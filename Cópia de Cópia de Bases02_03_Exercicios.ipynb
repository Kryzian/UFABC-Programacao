# %% [markdown]
# # Funcionários - Exercícios (Bases de Dados)

# %% [markdown]
# Este notebook tem por objetivo possibilitar que você faça exercícios utilizando o arquivo funciona.csv
#
# O arquivo `funciona.csv` está disponível [nesse link](#https://drive.google.com/file/d/1id-MxIdlA5pG0iJROsmxLzsBahvtNExc/view?usp=sharing) caso queira fazer o download. Mas as instruções para abrir e visualizar o arquivo já constam na célula abaixo.

# %%
import pandas as pd 
codigo = "1id-MxIdlA5pG0iJROsmxLzsBahvtNExc"
arquivo = "https://drive.google.com/u/3/uc?id=" + codigo + "&export=download"
# Base de Dados de Funcionarios
# Note a especificação de SEPARADOR (ponto e vírgula)
funciona = pd.read_csv(arquivo, sep = ";")
funciona.head()
# Out:
#    Codigo Escolaridade Genero  Idade_Anos  Tempo_Meses  Salario
# 0       2      1o Grau      M          20            8    19910
# 1       3      2o Grau      M          31           78    11180
# 2       4     Superior      M          54           89     8260
# 3       5      2o Grau      M          17            3    16350
# 4       6      1o Grau      F          24           88    16670

# %%
# Informações sobre os dados da tabela
funciona.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Codigo        20 non-null     int64
#  1   Escolaridade  20 non-null     object
#  2   Genero        20 non-null     object
#  3   Idade_Anos    20 non-null     int64
#  4   Tempo_Meses   20 non-null     int64
#  5   Salario       20 non-null     int64
# dtypes: int64(4), object(2)
# memory usage: 1.1+ KB

# %% [markdown]
# Nas três células abaixo você pode "treinar" seus exercícios. Você pode reusar a mesma célula para outro exercício. E você pode criar mais células.

# %%
#Q3 semana 2
import pandas as pd
funciona= pd.read_csv("https://drive.google.com/u/3/uc?id=1id-MxIdlA5pG0iJROsmxLzsBahvtNExc" , sep = ";")
supfunciona = funciona.query('Escolaridade.str.contains("Superior")', engine = 'python')
print(supfunciona)
# Out:
#    Codigo Escolaridade Genero  Idade_Anos  Tempo_Meses  Salario
# 2       4     Superior      M          54           89     8260
# 9      11     Superior      F          72           58    14020

# %%
#Q4 semana 2
import pandas as pd
funciona= pd.read_csv("https://drive.google.com/u/3/uc?id=1id-MxIdlA5pG0iJROsmxLzsBahvtNExc" , sep = ";")
print(funciona.query("Genero == 'M' & Idade_Anos > 50"))
# Out:
#     Codigo Escolaridade Genero  Idade_Anos  Tempo_Meses  Salario
# 2        4     Superior      M          54           89     8260
# 7        9      1o Grau      M          65           99     1980
# 10      12      2o Grau      M          58           72     1890
# 12      14      1o Grau      M          65           80    13760
# 13      15      2o Grau      M          58           61    11530
# 15      17      1o Grau      M          52           25    18420

# %%
#Q5 semana 2
import pandas as pd
funciona= pd.read_csv("https://drive.google.com/u/3/uc?id=1id-MxIdlA5pG0iJROsmxLzsBahvtNExc" , sep = ";")
funciona1 = funciona [["Codigo","Escolaridade","Idade_Anos","Salario"]]
print(funciona1.query("Escolaridade == '1o Grau' & Idade_Anos > 60"))
# Out:
#     Codigo Escolaridade  Idade_Anos  Salario
# 5        7      1o Grau          74    18130
# 7        9      1o Grau          65     1980
# 12      14      1o Grau          65    13760

# %%
#Q6 semana 2
import pandas as pd
funciona= pd.read_csv("https://drive.google.com/u/3/uc?id=1id-MxIdlA5pG0iJROsmxLzsBahvtNExc" , sep = ";")
print( funciona.sort_values(by=["Escolaridade","Salario"], ascending =[True,True]))
# Out:
#     Codigo Escolaridade Genero  Idade_Anos  Tempo_Meses  Salario
# 19      20      1o Grau      F          41           38     1610
# 7        9      1o Grau      M          65           99     1980
# 16      18      1o Grau      F          50           78     5100
# 14      16      1o Grau      M          38           93     6680
# 18      19      1o Grau      F          42           73     7630
# 6        8      1o Grau      M          23           69    10350
# 12      14      1o Grau      M          65           80    13760
# 4        6      1o Grau      F          24           88    16670
# 17       1      1o Grau      F          56           75    17600
# 5        7      1o Grau      F          74           77    18130
# 15      17      1o Grau      M          52           25    18420
# 0        2      1o Grau      M          20            8    19910
# 10      12      2o Grau      M          58           72     1890
# ...

# %%
#Q7 semana 2
import pandas as pd
funciona= pd.read_csv("https://drive.google.com/u/3/uc?id=1id-MxIdlA5pG0iJROsmxLzsBahvtNExc" , sep = ";")
print( funciona.groupby("Escolaridade")["Escolaridade"].count())
# Out:
# Escolaridade
# 1o Grau     12
# 2o Grau      6
# Superior     2
# Name: Escolaridade, dtype: int64

# %%
#Q8 semana 2
import pandas as pd
funciona= pd.read_csv("https://drive.google.com/u/3/uc?id=1id-MxIdlA5pG0iJROsmxLzsBahvtNExc" , sep = ";")
print(funciona.groupby("Escolaridade")["Salario"].max())
# Out:
# Escolaridade
# 1o Grau     19910
# 2o Grau     16350
# Superior    14020
# Name: Salario, dtype: int64

# %%
import pandas as pd
funciona= pd.read_csv("funciona.csv" , sep = ";")
print(funciona["Salario"].max())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-ee110012ad9a> in <module>()
#       1 import pandas as pd
# ----> 2 funciona= pd.read_csv("funciona.csv" , sep = ";")
#       3 print(funciona["Salario"].max())
#
# ...
